# %% [markdown]
# ### Dictionaries

# %% [markdown]
# # Recall of list :

# %%
names = ["ali","haider","alex"]

# %% [markdown]
# # Key:Value

# %%
person = {
    "id":"45510-0000-1",
    "name":"Ali",
    "address":"Abc Karachi"
}

# %% [markdown]
# ## Methods of Reading Data:
# - method-1:

# %%
person["id"]
# Out:
# '45510-0000-1'

# %%
person["name"]
# Out:
# 'Ali'

# %%
person.get("name")
# Out:
# 'Ali'

# %%
# Method-2:

# %%
person.get("id","id not available")
# Out:
# '45510-0000-1'

# %%
person.get("cnic","id not available")
# Out:
# 'id not available'

# %%
contacts = {
    "name":"Ali",
    "contact":"03350000000"
}

# %%
bio_data_lst = ['Umair', 30, 'Orangi Town']

# %%
bio_data[2]
# Out:
# 'Orangi Town'

# %%
bio_data_dict1 = {'first_name': 'Umair', 'last_name': 'Nawaz', 'address': 'Orangi Town'}

# %%
type(bio_data_dict)
# Out:
# dict

# %%
print(bio_data_dict['last_name'])
print(bio_data_dict['address'])
# Out:
# Nawaz
# Orangi Town

# %%
bio_data_lst.append('CDE')
bio_data_lst
# Out:
# ['Umair', 30, 'Orangi Town', 'CDE', 'CDE', 'CDE']

# %%
bio_data_dict['Course'] = 'CDE'

# %%
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'address': 'Orangi Town',
#  'Course': 'CDE'}

# %%
bio_data_dict['Course'] = 'Cloud Data Engineering'
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'address': 'Orangi Town',
#  'Course': 'Cloud Data Engineering'}

# %%
bio_data_lst
# Out:
# ['Umair', 30, 'Orangi Town', 'CDE', 'CDE', 'CDE']

# %%
del bio_data_lst[-2]
bio_data_lst
# Out:
# ['Umair', 30, 'Orangi Town', 'CDE']

# %%
del bio_data_dict['Course']
bio_data_dict
# Out:
# {'first_name': 'Umair', 'last_name': 'Nawaz', 'address': 'Orangi Town'}

# %%
bio_data_dict.get('last_name')
# Out:
# 'Nawaz'

# %%
bio_data_dict.items()
# Out:
# dict_items([('first_name', 'Umair'), ('last_name', 'Nawaz'), ('address', 'Orangi Town')])

# %%
bio_data_dict.keys()
# Out:
# dict_keys(['first_name', 'last_name', 'address'])

# %%
bio_data_dict.values()
# Out:
# dict_values(['Umair', 'Nawaz', 'Orangi Town'])

# %%
last_of_list = bio_data_lst.pop()
last_of_list
# Out:
# 'CDE'

# %%
bio_data_dict
# Out:
# {'first_name': 'Umair', 'last_name': 'Nawaz'}

# %%
bio_data_dict.pop('address')

# %%
bio_data_dict.popitem()
# Out:
# ('address', 'MALIR')

# %%
bio_data_dict.update({"address": "Orangi Town"})
print(bio_data_dict)
# Out:
# {'first_name': 'Umair', 'last_name': 'Nawaz', 'address': 'Orangi Town'}

# %%
bio_data_dict.setdefault('city')
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'address': 'Orangi Town',
#  'city': None}

# %%
bio_data_dict.setdefault('city', 'Karachi')

# %%
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'address': 'Orangi Town',
#  'city': None}

# %%
bio_data_dict.setdefault('province', 'Sindh')
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'city': None,
#  'province': 'Sindh'}

# %%
umair_lst['name']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 umair_lst['name']
#
# NameError: name 'umair_lst' is not defined

# %%
umair_lst['name]
# Out:
#   Cell In[64], line 1
#     umair_lst['name]
#               ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
age = 20
age
# Out:
# 20

# %%
20 + "20"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 20 + "20"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'address': 'Orangi Town',
#  'city': None,
#  'province': 'Sindh'}

# %%
bio_data_dict.pop('address')
bio_data_dict
# Out:
# {'first_name': 'Umair',
#  'last_name': 'Nawaz',
#  'city': None,
#  'province': 'Sindh'}

# %%
bio_data_lst.item
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 1
# ----> 1 bio_data_lst.item
#
# AttributeError: 'list' object has no attribute 'item'

# %%
20%0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 20%0
#
# ZeroDivisionError: integer modulo by zero

# %%
bio_data_lst
# Out:
# ['Umair', 30, 'Orangi Town', 'CDE']

# %%
for ele in bio_data_lst:
    print(ele)
# Out:
# Umair
# 30
# Orangi Town
# CDE

# %%
names = ['Umair', 'Noman', 'Salman']

# %%
for name in names:
    print(f'Hi {name}, You are invited!')
# Out:
# Hi Umair, You are invited!
# Hi Noman, You are invited!
# Hi Salman, You are invited!

# %%
bio_data_dict
# Out:
# {'first_name': 'Umair', 'last_name': 'Nawaz', 'address': 'Orangi Town'}

# %%
for i in bio_data_dict.values():
    print(i)
# Out:
# Umair
# Nawaz
# Orangi Town

# %%
for i in bio_data_dict.keys():
    print(i)
# Out:
# first_name
# last_name
# address

# %%
for i, j in bio_data_dict.items():
    print(i, j)
# Out:
# first_name Umair
# last_name Nawaz
# address Orangi Town
