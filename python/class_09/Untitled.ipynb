# %%
def display_name():
    user_input = input("Enter Your Name: ") # Umair
    return (user_input)

# %%
display_name()
# print(type(name))
# Out:
# Enter Your Name:  Umair
# 'Umair'

# %%
user = "Ali"

# %%
user
# Out:
# 'Ali'

# %%
user_input
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 user_input
#
# NameError: name 'user_input' is not defined

# %%
def generate_password():
    name = display_name() # --> 'Umair'
    name = name + "232@"
    print(name)

# %%
generate_password()
# Out:
# Enter Your Name:  Umair
# Ali232@

# %% [markdown]
# ### Task:
# - Create a simple calculator with features like addition, subtraction, multiplication and division.

# %%
def calc ():
    fnum = int(input("Enter first number"))
    snum = int(input("Enter Second Number"))
    opt = input("Enter Operator")
    if opt == '+':
        tot = fnum + snum
    if opt == '-':
        tot = fnum - snum
    if opt == '*':
        tot = fnum * snum
    if opt == '/':
        tot = fnum / snum
    return tot

# %%
calc ()
# Out:
# Enter first number 78
# Enter Second Number 5
# Enter Operator /
# 15.6

# %% [markdown]
# ### While Loop

# %%
lst = [1, 2, 3, 4, 5]

# %%
for i in lst:
    print("Ali")
# Out:
# Ali
# Ali
# Ali
# Ali
# Ali

# %%
num = 2
while num > 0:
    print('Ali')
    num -= 1
    print(num)
# Out:
# Ali
# 1
# Ali
# 0

# %%
2 > 0
# Out:
# True

# %% [markdown]
# You need to ask a city name from user until he give a quit test so you should check in the list wheather the city given by user is a clean city or not.

# %%
clean_cities = ["Islamabad", "Karachi"]

# %%
user_city = input("Enter Your City: ")

for city in clean_cities:
    if user_city == city:
        print(f"{user_city} is a clean city.")
# Out:
# Enter Your City:  Islamabad
# Islamabad is a clean city.

# %%
user_input = ""
# user_input = input("Enter a city to check or quit to stop the code: ")

while user_input != "quit":
    user_input = input("Enter a city to check or quit to stop the code: ")
    # if user_input == "quit":
        # break
        # print("hi")
        
    if user_input != "quit":
    for city in clean_cities:
        if user_input == city:
            print(f"{user_input} is a clean city.")
# Out:
# Enter a city to check or quit to stop the code:  quit
# hi

# %% [markdown]
# ### Task:
# - create a number guessing game, where you will have a secret number and you will use a while to take an input from user and match the number, if the number matches so display a congratulation message otherwise ask the number again.

# %%
secret_number = 23
num = 0

while num != secret_number:
    num = int(input("Enter your number"))
    if num == secret_number:
        print("Congratulation")
    else:
        print("Try Again")
# Out:
# Enter your number 10
# Try Again
# Enter your number 13
# Try Again
# Enter your number 23
# Congratulation

# %%
def cars():
    pass

# %%
name = "Umair"
fathers_name = "Ali"

# %%
print(type(name))
print(type(fathers_name))
# Out:
# <class 'str'>
# <class 'str'>

# %%
class str

# %%
lst = []

for i in range(1, 100):
    lst.append(i)
